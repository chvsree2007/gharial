# %%
import pandas as pd
df = pd.read_excel('test_data.xlsx','Sheet7')
df
# Out:
#          Day       City  Temp  Wind
# 0 2018-01-01  Hyderabad    33  70.0
# 1 2018-01-02    Chennai    23  60.0
# 2 2018-01-03     Mumbai    45  40.0
# 3 2018-01-04     Mumbai    34  32.0
# 4 2018-01-05    Chennai    33   NaN
# 5 2018-01-06  Hyderabad    23  25.0
# 6 2018-01-07      Delhi    45   2.0
# 7 2018-01-08  Bangalore    43  24.0
# 8 2018-01-09      Delhi    42  56.0

# %%
# df2 = df.pivot(index='Day',columns='City')
# #df2 = df.pivot(index='City',columns='Day')
# df2 = df.pivot(index='Day',columns='City',values='Temp')
# df2

# %%
df = pd.read_excel('test_data.xlsx','Sheet8')
#df
#df.pivot_table(index='City',columns='Day')
#df.pivot_table(index='City',columns='Day',values='Temp',aggfunc='sum')
df.pivot_table(index='Day',columns='City',values='Temp',aggfunc='mean',margins=True)
# Out:
# City                 Bangalore  Chennai  Delhi  Hyderabad  Mumbai        All
# Day
# 2018-01-01 00:00:00        NaN     30.0    NaN  33.000000     NaN  31.500000
# 2018-01-02 00:00:00        NaN     23.0    NaN        NaN     NaN  23.000000
# 2018-01-03 00:00:00        NaN      NaN    NaN        NaN    45.0  45.000000
# 2018-01-04 00:00:00        NaN      NaN    NaN        NaN    34.0  34.000000
# 2018-01-05 00:00:00        NaN     32.5    NaN        NaN     NaN  32.500000
# 2018-01-06 00:00:00        NaN      NaN    NaN  22.000000     NaN  22.000000
# 2018-01-07 00:00:00        NaN      NaN   45.0        NaN     NaN  45.000000
# 2018-01-08 00:00:00       43.0      NaN    NaN        NaN     NaN  43.000000
# 2018-01-09 00:00:00        NaN      NaN   42.0        NaN     NaN  42.000000
# All                       43.0     29.5   43.5  25.666667    39.5  33.666667

# %%
df = pd.read_excel('test_data.xlsx','Sheet9')
df
# Out:
#           Day     City  Temp  Wind
# 0  2018-01-01  Chennai    33  70.0
# 1  2018-06-01  Chennai    30  69.0
# 2  2018-01-02  Chennai    23  60.0
# 3  2018-02-03  Chennai    45  40.0
# 4  2018-02-04  Chennai    34  32.0
# 5  2018-04-05  Chennai    33   NaN
# 6  2018-01-05  Chennai    32  60.0
# 7  2018-05-06  Chennai    23  25.0
# 8  2018-01-06  Chennai    21  27.0
# 9  2018-05-07  Chennai    45   2.0
# 10 2018-01-08  Chennai    43  24.0
# 11 2018-06-09  Chennai    42  56.0

# %%
type(df['Day'][0])
df.pivot_table(index=pd.Grouper(freq='M',key='Day'),columns='Temp')
# Out:
#             Wind
# Temp          21    23    30    32    33    34    42    43    45
# Day
# 2018-01-31  27.0  60.0   NaN  60.0  70.0   NaN   NaN  24.0   NaN
# 2018-02-28   NaN   NaN   NaN   NaN   NaN  32.0   NaN   NaN  40.0
# 2018-05-31   NaN  25.0   NaN   NaN   NaN   NaN   NaN   NaN   2.0
# 2018-06-30   NaN   NaN  69.0   NaN   NaN   NaN  56.0   NaN   NaN

# %%
df = pd.read_excel('test_data.xlsx','Sheet10')
df
df2 = pd.melt(df,id_vars=['Day'])
# df2 = pd.melt(df,id_vars=['Day'],var_name='City',value_name='Temp')

# df2
df2[df2['variable']=='Hyderabad']
# Out:
#           Day   variable  value
# 0  2018-01-01  Hyderabad   33.0
# 1  2018-01-01  Hyderabad   30.0
# 2  2018-01-02  Hyderabad   23.0
# 3  2018-01-03  Hyderabad   45.0
# 4  2018-01-04  Hyderabad   34.0
# 5  2018-01-05  Hyderabad   33.0
# 6  2018-01-05  Hyderabad   32.0
# 7  2018-01-06  Hyderabad   23.0
# 8  2018-01-06  Hyderabad   21.0
# 9  2018-01-07  Hyderabad   45.0
# 10 2018-01-08  Hyderabad   43.0
# 11 2018-01-09  Hyderabad   42.0

# %%
df = pd.read_excel('test_data.xlsx','Sheet11',header=[0,1])
df
df.stack()
# Out:
#              Price  Price to Earning Ratio(P/E) Unnamed: 0_level_0
# 0 Company      NaN                          NaN         2019-05-06
#   Facebook   155.0                        157.0                NaT
#   Google     156.0                        321.0                NaT
#   Microsoft  157.0                        342.0                NaT
# 1 Company      NaN                          NaN         2019-06-06
#   Facebook   145.0                        132.0                NaT
#   Google     146.0                        564.0                NaT
#   Microsoft  143.0                        234.0                NaT
# 2 Company      NaN                          NaN         2019-07-06
#   Facebook   145.0                        121.0                NaT
#   Google     145.0                        234.0                NaT
#   Microsoft  144.0                        665.0                NaT
# 3 Company      NaN                          NaN         2019-08-06
# ...

# %%
df = pd.read_excel('country_handedness.xlsx')
df
#df.stack()
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   24      Right
# 2    Peter         USA    Male   12       Left
# 3     John  Bangladesh    Male   34       Left
# 4   Fatima  Bangladesh  Female   23       Left
# 5   Khadir       India    Male   22      Right
# 6   Dhaval       India    Male   33      Right
# 7   Sudhir       India    Male   44      Right
# 8   Parvir       India    Male   55       Left
# 9      Yan       China  Female   21       Left
# 10    Juan       China    Male   23      Right

# %%
pd.crosstab(df.Nationality,df.Handedness)
pd.crosstab(df.Sex,df.Handedness)
pd.crosstab(df.Sex,df.Handedness,margins=True)
pd.crosstab([df.Sex],[df.Handedness,df.Nationality])
pd.crosstab([df.Sex,df.Nationality],[df.Handedness])
pd.crosstab([df.Sex,df.Nationality],[df.Handedness=='Left'])

#pd.crosstab([df.Sex,df.Nationality],[df.Handedness],normalize='index')
# Out:
# Handedness          False  True
# Sex    Nationality
# Female Bangladesh       0      1
#        China            0      1
#        USA              2      0
# Male   Bangladesh       0      1
#        China            1      0
#        India            3      1
#        USA              0      1

# %%
df=pd.read_csv('AAPL.csv',parse_dates=['Date'],index_col='Date')
# type(df.Date[0])
# df.index
# df.ndim
# df.empty
# df.size
# df.values
# df.dtypes
# df.shape
df

df["2019-05-16":"2019-05-24"]
df.Close
df.Close.resample('M').mean()

df.Close.resample('M').plot()
#df.Open.resample('W',convention='end')#.mean().plot()
#%matplotlib inline
#df.Close.resample('M').mean().plot()
#df['2019-05-16':'2019-05-23']
# Out:
# Date
# 2019-05-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2019-06-30    AxesSubplot(0.125,0.2;0.775x0.68)
# Freq: M, Name: Close, dtype: object

# %%
df=pd.read_excel('AAPL.xlsx','AAPL',parse_dates=['Date'],index_col='Date')
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-16  189.910004  192.470001  188.839996  190.080002  190.080002
# 2019-05-17  186.929993  190.899994  186.759995  189.000000  189.000000
# 2019-05-20  183.520004  184.350006  180.279999  183.089996  183.089996
# 2019-05-21  185.220001  188.000000  184.699997  186.600006  186.600006
# 2019-05-22  184.660004  185.710007  182.550003  182.779999  182.779999
# 2019-05-23  179.800003  180.539993  177.809998  179.660004  179.660004
# 2019-05-24  180.199997  182.139999  178.619995  178.970001  178.970001
# 2019-05-28  178.919998  180.589996  177.910004  178.229996  178.229996
# 2019-05-29  176.419998  179.350006  176.000000  177.380005  177.380005
# 2019-05-30  177.949997  179.229996  176.669998  178.300003  178.300003
# 2019-05-31  176.229996  177.990005  174.990005  175.070007  175.070007
# 2019-06-03  175.600006  177.919998  170.270004  173.300003  173.300003
# ...

# %%
df=pd.read_excel('AAPL.xlsx','Sheet1')
df
rng = pd.date_range(start="5/17/2019",end="6/14/2019",freq='B')
rng.shape
df.set_index(rng,inplace=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-05-17  189.910004  192.470001  188.839996  190.080002  190.080002
# 2019-05-20  186.929993  190.899994  186.759995  189.000000  189.000000
# 2019-05-21  183.520004  184.350006  180.279999  183.089996  183.089996
# 2019-05-22  185.220001  188.000000  184.699997  186.600006  186.600006
# 2019-05-23  184.660004  185.710007  182.550003  182.779999  182.779999
# 2019-05-24  179.800003  180.539993  177.809998  179.660004  179.660004
# 2019-05-27  180.199997  182.139999  178.619995  178.970001  178.970001
# 2019-05-28  178.919998  180.589996  177.910004  178.229996  178.229996
# 2019-05-29  176.419998  179.350006  176.000000  177.380005  177.380005
# 2019-05-30  177.949997  179.229996  176.669998  178.300003  178.300003
# 2019-05-31  176.229996  177.990005  174.990005  175.070007  175.070007
# 2019-06-03  175.600006  177.919998  170.270004  173.300003  173.300003
# ...

# %%
df["2019-05-30":"2019-06-11"].Close.mean()
# Out:
# 183.5122222222222

# %%
df.asfreq('D',method='pad')
df.asfreq('D',method='pad').shape
df.asfreq('W',method='pad')
#df.asfreq('H',method='pad')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-05-19  189.910004  192.470001  188.839996  190.080002  190.080002
# 2019-05-26  179.800003  180.539993  177.809998  179.660004  179.660004
# 2019-06-02  176.229996  177.990005  174.990005  175.070007  175.070007
# 2019-06-09  186.509995  191.919998  185.770004  190.149994  190.149994
#
#               Volume
# 2019-05-19  33031400
# 2019-05-26  36529700
# 2019-06-02  27043600
# 2019-06-09  30684400

# %%
rng = pd.date_range(start="1/1/2017",periods=72,freq='B')
rng
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05',
#                '2017-01-06', '2017-01-09', '2017-01-10', '2017-01-11',
#                '2017-01-12', '2017-01-13', '2017-01-16', '2017-01-17',
#                '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31', '2017-02-01', '2017-02-02',
#                '2017-02-03', '2017-02-06', '2017-02-07', '2017-02-08',
#                '2017-02-09', '2017-02-10', '2017-02-13', '2017-02-14',
#                '2017-02-15', '2017-02-16', '2017-02-17', '2017-02-20',
#                '2017-02-21', '2017-02-22', '2017-02-23', '2017-02-24',
#                '2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10', '2017-03-13', '2017-03-14',
# ...

# %%
import numpy as np
ts = pd.Series(np.random.randint(1,10,len(rng)),index=rng)
ts.head()
# Out:
# 2017-01-02    9
# 2017-01-03    7
# 2017-01-04    1
# 2017-01-05    8
# 2017-01-06    5
# Freq: B, dtype: int32

# %%
df=pd.read_excel('AAPL.xlsx','Sheet1')
df
pd.date_range(start="7/1/2017",end="21/7/2017",freq='B')
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
# dates = ['2017-01-05','jan 5 2017','5th Jan 2017','5th January 2018','01/05/2017','2017/01/05','2017.01.05']
# pd.to_datetime(dates)

# dates = ['2017-01-05','jan 5 2017','5th Jan 2017','5th January 2018','01/05/2017','2017/01/05','2017.01.05','abc']
# pd.to_datetime(dates,errors='ignore')
# pd.to_datetime(dates,errors='coerce')

dates = ['2017-01-05 2:30 PM','jan 5th 2017 14:30:02','5th Jan 2017','5th January 2018','01/05/2017','2017/01/05','2017.01.05','abc']
pd.to_datetime(dates,errors='ignore')
pd.to_datetime(dates,errors='coerce')

ts=1501356749
dt=pd.to_datetime(ts)
dt
# Out:
# Timestamp('1970-01-01 00:00:01.501356749')

# %%
m=pd.Period('2016-12',freq='M')
m
# Out:
# Period('2016-12', 'M')

# %%
d=pd.Period('2017-12-1',freq='d')
d
d+1
# Out:
# Period('2017-12-02', 'D')

# %%
h=pd.Period('2018-2-03 12:30:00 PM',freq='H')
h
h+5
h-4
dir(h)
h.start_time
h.end_time
# Out:
# Timestamp('2018-02-03 12:59:59.999999999')

# %%
q=pd.Period('2017Q1')
q=pd.Period('2017Q1',freq='Q-JAN')
q.start_time
q.end_time
# Out:
# Timestamp('2016-04-30 23:59:59.999999999')

# %%
idx=pd.period_range('2016','2019',freq='M')#,freq='Q-JAN')
idx
# Out:
# PeriodIndex(['2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#              '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
#              '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#              '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#              '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#              '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#              '2019-01'],
#             dtype='period[M]', freq='M')

# %%
ps=pd.Series(np.random.randn(len(idx)),idx)
ps
#ps.to_timestamp()
# Out:
# 2016-01    0.020661
# 2016-02   -0.025921
# 2016-03   -0.444124
# 2016-04   -1.139560
# 2016-05    0.387825
# 2016-06    1.042639
# 2016-07    0.695823
# 2016-08   -0.642327
# 2016-09   -0.345347
# 2016-10    0.430535
# 2016-11   -1.120983
# 2016-12   -0.348213
# 2017-01   -1.808889
# 2017-02   -1.543330
# 2017-03   -0.669436
# 2017-04   -0.886516
# 2017-05    0.159107
# 2017-06    0.458880
# 2017-07   -0.943993
# 2017-08    0.539607
# 2017-09   -1.032990
# 2017-10   -0.925134
# 2017-11    0.061496
# 2017-12    0.336508
# 2018-01    0.429061
# 2018-02   -0.116373
# 2018-03    1.003735
# 2018-04    1.738328
# 2018-05   -0.019490
# 2018-06   -1.016208
# 2018-07   -1.092634
# 2018-08    0.265563
# 2018-09    1.391313
# 2018-10   -0.224375
# 2018-11    0.053308
# 2018-12   -1.000485
# 2019-01    0.662727
# Freq: M, dtype: float64

# %%
ps.shape
# Out:
# (37,)

# %%
df=pd.read_excel('AAPL.xlsx','Sheet2')
df
# Out:
#        Item  2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# 0   Revenue   11456   76755   75788   11331   24234
# 1  Expenses   98789    8787    8786    6567   24343
# 2    Profit  876578   87979   67665   98989   75655

# %%
df.set_index('Item',inplace=True)
df
# Out:
#           2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# Item
# Revenue    11456   76755   75788   11331   24234
# Expenses   98789    8787    8786    6567   24343
# Profit    876578   87979   67665   98989   75655

# %%
df = df.T
df
# Out:
# Index(['2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1'], dtype='object')

# %%
df.index
# df.index[0]
# type(df.index[0])
# Out:
# Index(['2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1'], dtype='object')

# %%
df.index=pd.PeriodIndex(df.index,freq='Q')
df.index
# Out:
# PeriodIndex(['2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1'], dtype='period[Q-DEC]', freq='Q-DEC')

# %%
df['start date'] = df.index.map(lambda x: x.start_time)
df
# Out:
# Item    Revenue  Expenses  Profit start date
# 2017Q1    11456     98789  876578 2017-01-01
# 2017Q2    76755      8787   87979 2017-04-01
# 2017Q3    75788      8786   67665 2017-07-01
# 2017Q4    11331      6567   98989 2017-10-01
# 2018Q1    24234     24343   75655 2018-01-01

# %%
df['end date'] = df.index.map(lambda x: x.end_time)
df
# Out:
# Item    Revenue  Expenses  Profit start date                      end date
# 2017Q1    11456     98789  876578 2017-01-01 2017-03-31 23:59:59.999999999
# 2017Q2    76755      8787   87979 2017-04-01 2017-06-30 23:59:59.999999999
# 2017Q3    75788      8786   67665 2017-07-01 2017-09-30 23:59:59.999999999
# 2017Q4    11331      6567   98989 2017-10-01 2017-12-31 23:59:59.999999999
# 2018Q1    24234     24343   75655 2018-01-01 2018-03-31 23:59:59.999999999

# %%
df=pd.read_excel('AAPL.xlsx','Sheet3',index_col='Date')
df
# Out:
#             Price
# Date
# 2019-01-01    234
# 2019-01-02    445
# 2019-01-03    565
# 2019-01-04    556
# 2019-01-05    433
# 2019-01-06    556
# 2019-01-07    324
# 2019-01-08    464
# 2019-01-09     78
# 2019-01-10    645

# %%
df.shift(1)
df.shift(-1)
# Out:
#             Price
# Date
# 2019-01-01  445.0
# 2019-01-02  565.0
# 2019-01-03  556.0
# 2019-01-04  433.0
# 2019-01-05  556.0
# 2019-01-06  324.0
# 2019-01-07  464.0
# 2019-01-08   78.0
# 2019-01-09  645.0
# 2019-01-10    NaN

# %%
df.tshift(1)
df['Prev Day'] = df['Price'].shift(1)
df
df['1 Day Change'] = df['Price']-df['Prev Day']
df
# Out:
#             Price  Prev Day  1 Day Change
# Date
# 2019-01-01    234       NaN           NaN
# 2019-01-02    445     234.0         211.0
# 2019-01-03    565     445.0         120.0
# 2019-01-04    556     565.0          -9.0
# 2019-01-05    433     556.0        -123.0
# 2019-01-06    556     433.0         123.0
# 2019-01-07    324     556.0        -232.0
# 2019-01-08    464     324.0         140.0
# 2019-01-09     78     464.0        -386.0
# 2019-01-10    645      78.0         567.0

# %% [raw]
# # Axis specifies the direction along which the means are computed. By default axis=0. This is consistent with the numpy.mean
# usage when axis is specified explicitly (in numpy.mean, axis==None by default, which computes the mean value over the flattened
# array) , in which axis=0 along the rows (namely, index in pandas), and axis=1 along the columns. For added clarity, one may
# choose to specify axis='index' (instead of axis=0) or axis='columns' (instead of axis=1).
#
# +------------+---------+--------+
# |            |  A      |  B     |
# +------------+---------+---------
# |      0     | 0.626386| 1.52325|----axis=1----->
# +------------+---------+--------+
#              |         |
#              | axis=0  |
#              ↓         ↓

# %%
df=pd.read_excel('AAPL.xlsx','Sheet1')#,index='Item')
print(df)
af = df.groupby(['Open','High'])
af.first()
df.mean(axis=1) # Along thee Row - for each Column value
df.mean(axis=0) # Along the Column - for each Row value
df.mean()
# Out:
#           Open        High         Low       Close   Adj Close    Volume
# 0   189.910004  192.470001  188.839996  190.080002  190.080002  33031400
# 1   186.929993  190.899994  186.759995  189.000000  189.000000  32879100
# 2   183.520004  184.350006  180.279999  183.089996  183.089996  38612300
# 3   185.220001  188.000000  184.699997  186.600006  186.600006  28364800
# 4   184.660004  185.710007  182.550003  182.779999  182.779999  29748600
# 5   179.800003  180.539993  177.809998  179.660004  179.660004  36529700
# 6   180.199997  182.139999  178.619995  178.970001  178.970001  23714700
# 7   178.919998  180.589996  177.910004  178.229996  178.229996  27948200
# 8   176.419998  179.350006  176.000000  177.380005  177.380005  28481200
# 9   177.949997  179.229996  176.669998  178.300003  178.300003  21218400
# 10  176.229996  177.990005  174.990005  175.070007  175.070007  27043600
# 11  175.600006  177.919998  170.270004  173.300003  173.300003  40396100
# ...

# %%
import pandas as pd
s=pd.Series([1,2,3])#,column=['a'])
type(s)
out =list(s)
type(out)
#s[0]
# Out:
# list

# %%
import pandas as pd
df = pd.read_excel('AAPL.xlsx','Sheet1')
df
df['C'][df['A']==df['B']]='Equal'
# #df['C'] = df.where(df['A']==df['B'],'Equal')
df.to_excel('AAPL.xlsx','Sheet5')
# Out:
# C:\Users\nxf53356\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'a':[1,2,6],
    'b':[4,5,6],
    'c':None
})
#df['c'][df['a']==2]='Has value'
#df[[df['a']==2],'c']='Has value'

#df['c'] = df.apply(lambda x:'Equal' if df['a']==df['b'] else 'not equal')#,axis=1)
#df['c'] = df.apply(lambda x:'Equal' if df['a']==df['b'] else 'not equal')#,axis=1)

# df['c']=np.where(df['a']==df['b'],'Equal','NotEq')
# df['c']=np.where(df['a']==df['b'],'Equal',None)
# df

def equal_method(df):
    if df['a'] == df['b']:
        return 'Equal'
    else:
        return 'Not Equal'

df['c'] = df.apply(equal_method,axis=1)
df['c']

df
# Out:
#    a  b          c
# 0  1  4  Not Equal
# 1  2  5  Not Equal
# 2  6  6      Equal

# %%
s=pd.Series([1,2,3,4])
type(s)
#print(dir(s))
s.to_list()
# Out:
# [1, 2, 3, 4]

# %%
dfl = pd.DataFrame(np.random.randn(5, 4),
              columns=list('ABCD'),
              index=pd.date_range('20130101', periods=5))
dfl
dir(dfl)
# Out:
# ['A',
#  'B',
#  'C',
#  'D',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
df = pd.DataFrame({'cost': [250, 150, 100],
                 'revenue': [100, 250, 300]},
                 index=['A', 'B', 'C'])
df
# Out:
#    cost  revenue
# A   250      100
# B   150      250
# C   100      300

# %%
k1 = df['cost']
k1
k2 = df['revenue']
type(k2)
df['result1'] = k1.eq(k2)
df['result2'] = k1.gt(k2)
df['result3'] = k1.lt(k2)
df['result3'] = k1.le(k2)
df
# Out:
#    cost  revenue result  result1  result2  result3
# A   250      100  Equal    False     True    False
# B   150      250  False    False    False     True
# C   100      300  False    False    False     True

# %%
import pandas as pd
df = pd.DataFrame({'Animal' : ['Falcon', 'Falcon',
                                'Parrot', 'Parrot'],
                    'Max Speed' : [380., 370., 24., 26.]})
df
df.mean()
df1 = df.groupby('Animal')
df1
# for d,d1 in df1:
#     print(d)
#     print(d1)
df.groupby(['Animal']).mean()
df.groupby(['Animal']).max()
# Out:
#         Max Speed
# Animal
# Falcon      380.0
# Parrot       26.0

# %%
india_weather = pd.DataFrame({
        'city':['Mumbai','Delhi','Bangalore'],
        'temperature':[32, 45, 35],
        'humidity': [80, 90, 40]
})

usa_weather = pd.DataFrame({
        'city':['Chicago','New York','Sanfransisco'],
        'temperature':[12, 25, 22],
        'humidity': [40, 50, 30]
})

df = pd.concat([india_weather, usa_weather])
df

df = pd.concat([india_weather, usa_weather],ignore_index=True)
df

df = pd.concat([india_weather, usa_weather], keys=['India', 'USA'])
df

#df.loc['India']
# Out:
#                  city  temperature  humidity
# India 0        Mumbai           32        80
#       1         Delhi           45        90
#       2     Bangalore           35        40
# USA   0       Chicago           12        40
#       1      New York           25        50
#       2  Sanfransisco           22        30

# %%
temperature_df = pd.DataFrame({
    'city': ['Mumbai', 'Bangalore', 'Delhi'],
    'temperature': [22,33,43]
})

windspeed_df = pd.DataFrame({
    'city': ['Delhi', 'Bangalore', 'Mumbai'],
    'windspeed': [12,23,13]
})
windspeed_df
df = pd.concat([temperature_df,windspeed_df], axis=1)
df
# Out:
#         city  temperature       city  windspeed
# 0     Mumbai           22      Delhi         12
# 1  Bangalore           33  Bangalore         23
# 2      Delhi           43     Mumbai         13

# %%
temperature_df = pd.DataFrame({
    'city': ['Mumbai', 'Bangalore', 'Delhi'],
    'temperature': [22,33,43]
},index=[0,1,2])

windspeed_df = pd.DataFrame({
    'city': ['Delhi', 'Bangalore', 'Mumbai'],
    'windspeed': [12,23,13]
},index=[2,1,0])
windspeed_df

df = pd.concat([temperature_df,windspeed_df], axis=1)
df
# Out:
#         city  temperature       city  windspeed
# 0     Mumbai           22     Mumbai         13
# 1  Bangalore           33  Bangalore         23
# 2      Delhi           43      Delhi         12

# %%
s =pd.Series(["Humid", "Dry", "Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temperature_df, s], axis=1)
df
# Out:
#         city  temperature  event
# 0     Mumbai           22  Humid
# 1  Bangalore           33    Dry
# 2      Delhi           43   Rain

# %%
temperature_df = pd.DataFrame({
    'city': ['Mumbai', 'Bangalore', 'Delhi','Pune'],
    'temperature': [22,33,43,34]
})

windspeed_df = pd.DataFrame({
    'city': ['Delhi', 'Bangalore', 'Mumbai','Kolkata'],
    'windspeed': [12,23,13,16]
})

df = pd.merge(temperature_df,windspeed_df)
df = pd.merge(temperature_df,windspeed_df, on="city")

df
# Out:
#         city  temperature  windspeed
# 0     Mumbai           22         13
# 1  Bangalore           33         23
# 2      Delhi           43         12

# %%
temperature_df = pd.DataFrame({
    'city': ['Mumbai', 'Bangalore', 'Delhi', "Hyderabad",'Pune'],
    'temperature': [22,33,43,32,31]
})

windspeed_df = pd.DataFrame({
    'city': ['Delhi', 'Bangalore', 'Mumbai',"Cochin"],
    'windspeed': [12,23,13,14]
})

df = pd.merge(temperature_df,windspeed_df, on="city", how="outer")
df
# Out:
#         city  temperature  windspeed
# 0     Mumbai         22.0       13.0
# 1  Bangalore         33.0       23.0
# 2      Delhi         43.0       12.0
# 3  Hyderabad         32.0        NaN
# 4       Pune         31.0        NaN
# 5     Cochin          NaN       14.0

# %%
temperature_df = pd.DataFrame({
    'city': ['Mumbai', 'Bangalore', 'Delhi', "Hyderabad"],
    'temperature': [22,33,43,32]
})

windspeed_df = pd.DataFrame({
    'city': ['Delhi', 'Bangalore', 'Mumbai',"Cochin"],
    'windspeed': [12,23,13,14]
})

df = pd.merge(temperature_df,windspeed_df, on="city", how="right")
df
# Out:
#         city  temperature  windspeed
# 0     Mumbai         22.0         13
# 1  Bangalore         33.0         23
# 2      Delhi         43.0         12
# 3     Cochin          NaN         14

# %%
temperature_df = pd.DataFrame({
    'city': ['Mumbai', 'Bangalore', 'Delhi', "Hyderabad"],
    'temperature': [22,33,43,32]
})

windspeed_df = pd.DataFrame({
    'city': ['Delhi', 'Bangalore', 'Mumbai',"Cochin"],
    'windspeed': [12,23,13,14]
})

df = pd.merge(temperature_df,windspeed_df, on="city", how="outer", indicator=True)
df
# Out:
#         city  temperature  windspeed      _merge
# 0     Mumbai         22.0       13.0        both
# 1  Bangalore         33.0       23.0        both
# 2      Delhi         43.0       12.0        both
# 3  Hyderabad         32.0        NaN   left_only
# 4     Cochin          NaN       14.0  right_only

# %%
df1 = pd.DataFrame({
    'city': ['Mumbai', 'Bangalore', 'Delhi', "Hyderabad"],
    'temperature': [22,33,43,32],
    'humidity': [12,13,23,10]

})

df2 = pd.DataFrame({
    'city': ['Delhi', 'Bangalore', 'Mumbai',"Cochin"],
    'temperature': [21,31,42,22],
    'humidity': [15,23,21,11]
})

df = pd.merge(df1,df2, on="city")
df
# Out:
#         city  temperature_x  humidity_x  temperature_y  humidity_y
# 0     Mumbai             22          12             42          21
# 1  Bangalore             33          13             31          23
# 2      Delhi             43          23             21          15

# %%
df = pd.merge(df1,df2, on="city", suffixes=('_left','_right'))
df
# Out:
#         city  temperature_left  humidity_left  temperature_right  \
# 0     Mumbai                22             12                 42
# 1  Bangalore                33             13                 31
# 2      Delhi                43             23                 21
#
#    humidity_right
# 0              21
# 1              23
# 2              15

# %%
df = pd.DataFrame({
    'day': ['1/1/2017','2/1/2017','3/1/2017','5/1/2017','3/1/2017','3/1/2017','2/1/2017','2/1/2017','1/1/2017'],
    'city': ['Delhi', 'Bangalore', 'Mumbai',"Cochin","Bangalore",'Cochin','Delhi','Mumbai','Bangalore'],
    'temperature': [21,31,42,22,23,20,19,34,27],
    'humidity': [15,23,21,11,10,14,15,17,9]
})
df
#df.set_index('day')
df.pivot(index='day', columns='city')
# Out:
#          temperature                      humidity
# city       Bangalore Cochin Delhi Mumbai Bangalore Cochin Delhi Mumbai
# day
# 1/1/2017        27.0    NaN  21.0    NaN       9.0    NaN  15.0    NaN
# 2/1/2017        31.0    NaN  19.0   34.0      23.0    NaN  15.0   17.0
# 3/1/2017        23.0   20.0   NaN   42.0      10.0   14.0   NaN   21.0
# 5/1/2017         NaN   22.0   NaN    NaN       NaN   11.0   NaN    NaN

# %%
df.pivot(index='day', columns='city', values='humidity')
# Out:
# city      Bangalore  Cochin  Delhi  Mumbai
# day
# 1/1/2017        9.0     NaN   15.0     NaN
# 2/1/2017       23.0     NaN   15.0    17.0
# 3/1/2017       10.0    14.0    NaN    21.0
# 5/1/2017        NaN    11.0    NaN     NaN

# %%
df.pivot_table(index='day', columns='city', aggfunc='mean')
df.pivot_table(index='day', columns='city', aggfunc='sum')
df.pivot_table(index='day', columns='city', aggfunc='mean',margins=True)
# Out:
#           humidity                                temperature               \
# city     Bangalore Cochin Delhi Mumbai        All   Bangalore Cochin Delhi
# day
# 1/1/2017       9.0    NaN  15.0    NaN  12.000000        27.0    NaN  21.0
# 2/1/2017      23.0    NaN  15.0   17.0  18.333333        31.0    NaN  19.0
# 3/1/2017      10.0   14.0   NaN   21.0  15.000000        23.0   20.0   NaN
# 5/1/2017       NaN   11.0   NaN    NaN  11.000000         NaN   22.0   NaN
# All           14.0   12.5  15.0   19.0  15.000000        27.0   21.0  20.0
#
#
# city     Mumbai        All
# day
# 1/1/2017    NaN  24.000000
# 2/1/2017   34.0  28.000000
# 3/1/2017   42.0  28.333333
# 5/1/2017    NaN  22.000000
# All        38.0  26.555556

# %%
type(df['day'][0])
# Out:
# str

# %%
df['day'] = pd.to_datetime(df['day'])
type(df['day'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.pivot_table(index=pd.Grouper(freq='M', key='day'), columns='city')
# Out:
#             humidity                     temperature
# city       Bangalore Cochin Delhi Mumbai   Bangalore Cochin Delhi Mumbai
# day
# 2017-01-31       9.0    NaN  15.0    NaN        27.0    NaN  21.0    NaN
# 2017-02-28      23.0    NaN  15.0   17.0        31.0    NaN  19.0   34.0
# 2017-03-31      10.0   14.0   NaN   21.0        23.0   20.0   NaN   42.0
# 2017-05-31       NaN   11.0   NaN    NaN         NaN   22.0   NaN    NaN

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'day': ['1/1/2017','2/1/2017','3/1/2017','5/1/2017','3/1/2017','3/1/2017','2/1/2017','2/1/2017','1/1/2017'],
    'city': ['Delhi', 'Bangalore', 'Mumbai',"Cochin","Bangalore",'Cochin','Delhi','Mumbai','Bangalore'],
    'temperature': [21,31,42,22,23,20,19,34,27],
    'humidity': [15,23,21,11,10,14,15,17,9]
})
#pd#.melt(df)#, id_vars=['day'])
df
df = df.replace(['Mumbai','Delhi', 21],['Bombay','New Delhi',22])
df

df = df.replace({
    'city':'Cochin',
    'temperature':31
},np.NaN)
df
# Out:
#         day       city  temperature  humidity
# 0  1/1/2017  New Delhi         22.0        15
# 1  2/1/2017  Bangalore          NaN        23
# 2  3/1/2017     Bombay         42.0        22
# 3  5/1/2017        NaN         22.0        11
# 4  3/1/2017  Bangalore         23.0        10
# 5  3/1/2017        NaN         20.0        14
# 6  2/1/2017  New Delhi         19.0        15
# 7  2/1/2017     Bombay         34.0        17
# 8  1/1/2017  Bangalore         27.0         9

# %%
df =pd.read_excel('tti_20june.xlsx')
df = df.replace({
    'TTI':'[A-Za-z_=1 =]',
},' ',regex=True)
df
# Out:
#                                                 TTI  Unnamed: 1  Unnamed: 2
# 0                                        23384              NaN         NaN
# 1                                               NaN         NaN         NaN
# 2                                       366246              NaN         NaN
# 3                                               NaN         NaN         NaN
# 4                                       702909              NaN         NaN
# 5                                               NaN         NaN         NaN
# 6                                        4482               NaN         NaN
# 7                                               NaN         NaN         NaN
# 8                                       382568              NaN         NaN
# 9                                               NaN         NaN         NaN
# 10                                      724088              NaN         NaN
# ...

# %%
import pandas as pd
df =pd.DataFrame({
    'row':['A','B','C'],
    'val':[12,13,'str1']
})
#df['val_label'] = ['True'][type(df.val) == int]
#if type(df['val'][0]) is int:
#    print("Integer")
#df.loc('A')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-09c331350a0b> in <module>
#       5 })
#       6 #df['val_label'] = ['True'][type(df.val) == int]
# ----> 7 df['row'][df.val is int]
#       8 #if type(df['val'][0]) is int:
#       9 #    print("Integer")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
# ...

# %%
def method(df):
    if type(df['val']) is str:
        return "True"
    else:
        return "False"
        
df['val_label'] = df.apply(method,axis=1)
# Out:
#   row   val val_label
# 0   A    12     False
# 1   B    13     False
# 2   C  str1      True
